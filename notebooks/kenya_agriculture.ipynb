# %% [markdown]
# ## Kenya Agriculture Analysis
#
#
# This project uses Apache Spark to analyze Kenya's agricultural production dataset obtained from FAOSTAT.
#
# The project demonstrates:
#
# - Loading data into Spark
# - Data cleaning
# - Data transformations
# - Big data analytics
# - Visualization of insights
